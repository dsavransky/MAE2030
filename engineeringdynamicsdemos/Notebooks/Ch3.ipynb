# %% [markdown]
# # Chapter 3 Demos
#
# Runs the demo functions in `engineeringdynamicsdemos.ch3`.
#
# The animation cells below are saved **unexecuted** (to keep this notebook small); run them to view the animations. The first animation cell sets `plt.rcParams["figure.dpi"] = 50`, which applies to all later animation cells.

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML

from engineeringdynamicsdemos import ch3

# %% [markdown]
# ## Simple Pendulum vs. SHO
#
# See Example 3.9. Compares the numerically integrated simple pendulum equations of motion with the analytical solution of the linearized (simple harmonic oscillator) equations, for a large and a small initial angle.

# %%
figs = ch3.compare_simple_pendulum_sho()
plt.show()

# %% [markdown]
# ## Simple Pendulum Animation
#
# See Example 3.11. Execute the following cell to view the animation. You can change the resolution of the generated figure by changing the value in the first line of code, and the time array `t` (duration and step) of the integration; longer/finer arrays take longer to render.

# %%
plt.rcParams["figure.dpi"] = 50
anim = ch3.simple_pendulum_animation(t=np.arange(0, 10, 1 / 20))
plt.close(anim._fig)
HTML(anim.to_jshtml())

# %% [markdown]
# ## Stationary vs. Accelerating Pendulum
#
# See Example 3.14. A stationary pendulum beside one in an accelerating box. With `stationary=True` the accelerating pendulum starts at rest in the accelerating frame. Execute the following cell to view the animation. You can change the resolution of the generated figure by changing the time array `t` (duration and step) of the integration; longer/finer arrays take longer to render.

# %%
anim = ch3.accel_pendulum_animation(t=np.arange(0, 5, 1 / 20))
plt.close(anim._fig)
HTML(anim.to_jshtml())

# %%
anim = ch3.accel_pendulum_animation(stationary=True, t=np.arange(0, 5, 1 / 20))
plt.close(anim._fig)
HTML(anim.to_jshtml())

# %% [markdown]
# ## Spring Pendulum Animation
#
# Animates a pendulum whose arm is a spring, alongside live traces of the arm length `r` and angle `theta`. Execute the following cell to view the animation. You can change the resolution of the generated figure by changing the time array `t` (duration and step) of the integration; longer/finer arrays take longer to render.

# %%
anim = ch3.spring_pendulum_animation(t=np.arange(0, 5, 1 / 20))
plt.close(anim._fig)
HTML(anim.to_jshtml())

# %% [markdown]
# ## Rotating Frame Animation
#
# See Sec. 3.4.2. A rigid body (cube) fixed in a frame $\mathcal{B}$ rotating about $\mathbf{\hat{e}}_3$, as seen in the inertial frame $\mathcal{I}$. `step_deg` sets the angular increment per frame (smaller is smoother but slower to render).

# %%
anim = ch3.rotating_frame_animation(step_deg=6)
plt.close(anim._fig)
HTML(anim.to_jshtml())
